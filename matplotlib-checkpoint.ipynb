# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt

# %%
plt.plot();

# %%
x= [1,2,3,4]
y =[5,6,7,6]
plt.xlabel("Vận tốc (m/s)")
plt.ylabel("Quãng đường (m)")
plt.title("Biểu đồ quãng đường và vận tốc")
plt.plot(x,y);

# %%
x= np.linspace(0,10,1000)
plt.style.use('seaborn-darkgrid')
plt.plot(x,np.sin(x),color = "black",label = "sinx");
plt.plot(x,np.cos(x),color = "red", label = "cosx")
#plt.xlim([2,8])
#plt.ylim[-0.5,0.5]
plt.axis([2,8,-0.5,0.5])
plt.legen;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 x= np.linspace(0,10,1000)
#       2 plt.style.use('seaborn-darkgrid')
#       3 plt.plot(x,np.sin(x),color = "black",label = "sinx");
#
# NameError: name 'np' is not defined

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
np.random.seed(42)
y = np.linspace(0,2,5)
x= np.arange(2,12,2)
z = np.random.rand(5)
color = np.random.rand(5)
fig , ax = plt.subplots();
ax.set(xlabel = "Quãng đường (10km)", ylabel= 'Thời gian', title ="Thống kê sự di chuyển của sinh viên")
ax.bar(x,z);
#ax.legend()
#ax.plot(x,y);
#ax.axis(minrow,maxrow,minco,maxco)

#plt.set(title =)

# %%
# set width of bar
barWidth = 0.25
plt.subplots(figsize =(12, 8))
 
# set height of bar
IT = [12, 30, 1, 8, 22]
ECE = [28, 6, 16, 5, 10]
CSE = [29, 3, 24, 25, 17]
 
# Set position of bar on X axis
br1 = np.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
 
# Make the plot
plt.bar(br1, IT, color ='r', width = 0.25,
     edgecolor ='grey', label ='IT')
plt.bar(br2, ECE, color ='g', width = barWidth,
        edgecolor ='grey', label ='ECE')
plt.bar(br3, CSE, color ='b', width = barWidth,
         edgecolor ='grey', label ='CSE')
 
#  Adding Xticks
plt.xlabel('Branch', fontweight ='bold', fontsize = 15);
plt.ylabel('Students passed', fontweight ='bold', fontsize = 15);
plt.xticks([h+barWidth for h in br1],['2015', '2016', '2017', '2018', '2019'],fontsize = 18, weight ="bold");

plt.legend()

# %%
fig, ax = plt.subplots(figsize = (20,10))
width = 0.25
IT = [12, 30, 1, 8, 22]
ECE = [28, 6, 16, 5, 10]
CSE = [29, 3, 24, 25, 17]
y = [y + width for y in x]
z = [z + width for z in y]
ax.bar(x, IT, width = width,label = "IT")
ax.bar(y,ECE,width = width, label = "ECE")
ax.bar(z,CSE,width = width, label = "CSE")
#ax.set_xticks([i for i in y],["2017","2018","2019","2020","2021"],weight = "bold",fontsize = 20)
ax.legend()

# %%
a = np.array([[1,2,3]])
b =["Bò","Gà","Chó"]
pd.DataFrame(index = ["Số lượng"], columns = b,data = a)
# Out:
#           Bò  Gà  Chó
# Số lượng   1   2    3
